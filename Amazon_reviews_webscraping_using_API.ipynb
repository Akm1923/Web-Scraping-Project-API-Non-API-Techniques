# %% [markdown]
# Using API

# %%
import pandas as pd
import requests

# %%
import requests

url = "https://real-time-amazon-data.p.rapidapi.com/product-reviews"

querystring = {"asin":"B07ZPKN6YR","country":"US","page":"1","sort_by":"TOP_REVIEWS","star_rating":"ALL","verified_purchases_only":"false","images_or_videos_only":"false","current_format_only":"false"}

headers = {
	"x-rapidapi-key": "1512b72dd9mshff3a96607c8021dp1bd61djsn7d3bda32bbc3",
	"x-rapidapi-host": "real-time-amazon-data.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'status': 'OK', 'request_id': 'a89922d4-ead5-45f8-8094-4760f4bcb2ed', 'parameters': {'asin': 'B07ZPKN6YR', 'country': 'US', 'sort_by': 'TOP_REVIEWS', 'verified_purchases_only': False, 'images_or_videos_only': False, 'current_format_only': False, 'star_rating': 'ALL', 'page': 1}, 'data': {'asin': 'B07ZPKN6YR', 'total_reviews': 12715, 'total_ratings': 55494, 'country': 'US', 'domain': 'www.amazon.com', 'reviews': [{'review_id': 'R3IP3AW6JCCIH6', 'review_title': 'EXCELLENT PHONE & BEYOND AMAZING SELLER/CUSTOMER SERVICE!!!', 'review_comment': "I honestly can’t say enough amazing things about my experience buying a renewed iPhone 11 from this seller and dealing with their customer service! I would 1000/10 recommend anyone and everyone even considering purchasing a phone from them to absolutely do so because you won’t be disappointed!!! But read below for the full story/review, both good and bad opinions.\n\nMy oldest daughter dropped her iPhone XR in the toilet and it completely died. Th
# ...

# %%
type(response.json())
# Out:
# dict

# %%
response.json()
# Out:
# {'status': 'OK',
#  'request_id': 'a89922d4-ead5-45f8-8094-4760f4bcb2ed',
#  'parameters': {'asin': 'B07ZPKN6YR',
#   'country': 'US',
#   'sort_by': 'TOP_REVIEWS',
#   'verified_purchases_only': False,
#   'images_or_videos_only': False,
#   'current_format_only': False,
#   'star_rating': 'ALL',
#   'page': 1},
#  'data': {'asin': 'B07ZPKN6YR',
#   'total_reviews': 12715,
#   'total_ratings': 55494,
#   'country': 'US',
#   'domain': 'www.amazon.com',
#   'reviews': [{'review_id': 'R3IP3AW6JCCIH6',
#     'review_title': 'EXCELLENT PHONE & BEYOND AMAZING SELLER/CUSTOMER SERVICE!!!',
# ...

# %%
df=pd.DataFrame(response.json()["data"]["reviews"])
df.head()
# Out:
#         review_id                                       review_title  \
# 0  R3IP3AW6JCCIH6  EXCELLENT PHONE & BEYOND AMAZING SELLER/CUSTOM...
# 1  R3VDU56XYE7XPV                        It’s was good for the price
# 2  R1HYB267C2CU84              Excellent condition/ looks brand new!
# 3   RSVGACWFTNLHY                           Nice phone, decent price
# 4  R3W0O4MBD95EI3                                              11/10
#
#                                       review_comment review_star_rating  \
# 0  I honestly can’t say enough amazing things abo...                  5
# 1  I recently had the iPhone 11, from games to ap...                  5
# 2  The phone is perfect. I ordered it in refurbis...                  5
# 3  I needed a new unlocked iPhone for my wife, si...                  4
# 4  Soooo perfect and pretty it’s like brand new. ...                  5
#
#                                          review_link  \
# 0  https://www.amazon.com/gp/customer-reviews/R3I...
# ...

# %%
df.shape
# Out:
# (10, 16)

# %% [markdown]
# There are only 10 reviews in page 1...

# %%
df_actual=pd.DataFrame()
df_actual.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
response.json()["data"]["reviews"]
# Out:
# [{'review_id': 'R3IP3AW6JCCIH6',
#   'review_title': 'EXCELLENT PHONE & BEYOND AMAZING SELLER/CUSTOMER SERVICE!!!',
# ...

# %% [markdown]
# I am running the loop 10 times only just to test

# %%
for i in range(1,11,1):
   url = "https://real-time-amazon-data.p.rapidapi.com/product-reviews"

   querystring = {"asin":"B07ZPKN6YR","country":"US","page":"1","sort_by":"TOP_REVIEWS","star_rating":"ALL","verified_purchases_only":"false","images_or_videos_only":"false","current_format_only":"false"}

   headers = {
       "x-rapidapi-key": "1512b72dd9mshff3a96607c8021dp1bd61djsn7d3bda32bbc3",
	     "x-rapidapi-host": "real-time-amazon-data.p.rapidapi.com"
       }


   response = requests.get(url, headers=headers, params=querystring)
   df_actual = pd.concat([df_actual, pd.DataFrame(response.json()["data"]["reviews"])], ignore_index=True)

# %%
df_actual
# Out:
#          review_id                                       review_title  \
# 0   R3IP3AW6JCCIH6  EXCELLENT PHONE & BEYOND AMAZING SELLER/CUSTOM...
# 1   R3VDU56XYE7XPV                        It’s was good for the price
# 2   R1HYB267C2CU84              Excellent condition/ looks brand new!
# 3    RSVGACWFTNLHY                           Nice phone, decent price
# 4   R3W0O4MBD95EI3                                              11/10
# ..             ...                                                ...
# 95  R3CUZ97IKJ0KRG     Phone works great and great customer service!!
# 96  R24SGFPU2A19GH                                             Great!
# 97  R2Q79RL02GKC4A                   Great Phone, Still Going Strong!
# 98  R19WIC5AMSJF0M                        So far so great, thank you.
# 99  R3A9V0SFLQJMZO                                             iPhone
#
#                                        review_comment review_star_rating  \
# ...

# %%
df_actual.shape
# Out:
# (100, 16)

# %%
df.to_csv("amazon_reviews.csv")
